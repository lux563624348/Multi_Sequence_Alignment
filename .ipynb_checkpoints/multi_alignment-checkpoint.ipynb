# %%
from datetime import datetime, date
import pandas as pd
import numpy as np
from src.MSA.objects import *
from src.MSA.levenshtein import *

# %%
def Main_Compute_Similarity_For_Pair(pair_name, df_p1, df_p2, col_seq, col_time, dict_sub_matrix, max_transposition_date):
    df_seq1 = df_p1.sort_values(col_time)
    df_seq2 = df_p2.sort_values(col_time)

    seq1 = ''.join(df_seq1.loc[:, col_seq])
    seq2 = ''.join(df_seq2.loc[:, col_seq])
    date1 = df_seq1.loc[:, col_time].values
    date2 = df_seq2.loc[:, col_time].values

    dict_sub_matrix = dict_sub_matrix
    similarity = Normalize_Levenshtein_Distance_Score(seq1, seq2, date1, date2, dict_sub_matrix, max_transposition_date)
    return similarity

def Levenshtein_Distance_with_Transposition_Date_No_Matrix(seq1, seq2, dates1, dates2, _dict_pre_matrix, max_transposition_date):
  """
  Calculates the Levenshtein distance between two sequences, considering transpositions.
  Args:
    seq1: The first sequence.
    seq2: The second sequence.
    dict_sub_matrix: Pandas DataFrame containing substitution distance.
  Returns:
    The Levenshtein distance between the two sequences.
  """
  seq1 = ["#"] +  [x for x in seq1]
  seq2 = ["#"] +  [x for x in seq2]
  dates1 = ["None"] + [x for x in dates1]
  dates2 = ["None"] + [x for x in dates2]

  m = len(seq1)
  n = len(seq2)
  # Create a distance matrix
  #dp = np.full((m, n), 0)  # Initialize with infinity to handle transpositions
  dp = [[0 for col in range(n)] for row in range(m)]
  # Fill the DP table
  for i in range(1, m):
    dp[i][0] = _dict_pre_matrix[seq1[i]]['Vins']
  for j in range(1, n):
    dp[0][j] = _dict_pre_matrix[seq2[j]]['Vins']
      
  # Fill the DP table
  # for rareness-weight
  w1,w2,w3 = -0.5, 0.75, 0.5
    
  for i in range(1, m):
    for j in range(1, n):
      # Standard costs
      insertion_cost = dp[i-1][j] + _dict_pre_matrix[seq1[i]]['Vins']  # (letter -> # )
      deletion_cost = dp[i][j-1] +  _dict_pre_matrix[seq2[j]]['Vins']  # ( # -> letter)
      # Substitution cost
      cost = ( min(_dict_pre_matrix[seq1[i]]['Vmtc'], _dict_pre_matrix[seq2[j]]['Vmtc']) if seq1[i] == seq2[j] # if match use mtc score
             else min(_dict_pre_matrix[seq1[i]]['Vsub'], _dict_pre_matrix[seq2[j]]['Vsub'])) ## if no match use sub score
      substitution_cost = dp[i-1][j-1] + cost
      #print ("insertion_cost, deletion_cost, substitution_cost", insertion_cost, deletion_cost, substitution_cost) 
      dp[i][j] = min(insertion_cost, deletion_cost, substitution_cost)
      # Handle transpositions with date constraint
      if ((i > 0) & (j > 0)):
          for idx_seq1  in range(1, m, 1):
              date_diff1 = abs((dates1[idx_seq1] - dates2[j]).days)
              if (date_diff1 < max_transposition_date):
                  tns_cost = _dict_pre_matrix[seq1[idx_seq1]]['Vtns'] ## Vtns = Vmtc * w3  ([0,1]) w3 = 0.5
                  sub_cost = _dict_pre_matrix[seq1[idx_seq1]]['Vsub']
                  cost = (tns_cost if seq1[idx_seq1] == seq2[j] else sub_cost)
                  transposition_cost = dp[i-1][j-1] + cost
                  dp[i][j] = min(dp[i][j], transposition_cost)
          for idx_seq2  in range(1, n, 1):
              date_diff2 = abs((dates1[i] - dates2[idx_seq2]).days)
              if (date_diff2 < max_transposition_date):
                  tns_cost = _dict_pre_matrix[seq2[idx_seq2]]['Vtns'] ## Vtns = Vmtc * w3  ([0,1]) w3 = 0.5
                  sub_cost = _dict_pre_matrix[seq2[idx_seq2]]['Vsub']
                  cost = (tns_cost if seq1[idx_seq1] == seq2[j] else sub_cost)                  
                  transposition_cost = dp[i-1][j-1] + cost
                  dp[i][j] = min(dp[i][j], transposition_cost)

  return dp[m - 1][n - 1], dp

# %% [markdown]
# ## test matrix on algorithm change

# %%
def Levenshtein_Distance_with_Transposition_Date_Final(seq1, seq2, dates1, dates2, dict_sub_matrix, max_transposition_date):
    """
    Calculates the Levenshtein distance between two sequences, considering transpositions.
    Args:
    seq1: The first sequence.
    seq2: The second sequence.
    dict_sub_matrix: Pandas DataFrame containing substitution distance.
    Returns:
    The Levenshtein distance between the two sequences.
    """
    seq1 = ["#"] +  [x for x in seq1]
    seq2 = ["#"] +  [x for x in seq2]
    dates1 = ["None"] + [x for x in dates1]
    dates2 = ["None"] + [x for x in dates2]
    
    sizerow = len(seq1)
    sizecol = len(seq2)
    # Create a distance matrix
    dp = [[0 for col in range(sizecol)] for row in range(sizerow)]
    w1,w2,w3 = -0.5, 0.75, 0.5
    
    for i in range(1, sizerow):
        for j in range(1, sizecol):
            # Standard costs
            Vmtc_row = dict_sub_matrix[seq1[i]][seq1[i]]
            Vmtc_col = dict_sub_matrix[seq2[j]][seq2[j]]
            insertion_cost = dp[i][j-1] + w1*w2*min(Vmtc_row, Vmtc_col)  # ( # -> letter)
            deletion_cost = dp[i-1][j] + w1*w2*min(Vmtc_row, Vmtc_col)  # (letter -> # )
            # Substitution cost
            min_dp =  dp[i-1][j-1] #min(dp[i][j-1], dp[i-1][j-1], dp[i-1][j])
            if (seq1[i] != seq2[j]):
                sub_cost = min_dp + w1*min(Vmtc_row, Vmtc_col) # sub
            if (seq1[i] == seq2[j]): ## sub or tns or mtc
                if (abs((dates1[i] - dates2[j]).days) > max_transposition_date):
                    ## sub: same sequence, but out of date.
                    sub_cost = min_dp + w1*min(Vmtc_row, Vmtc_col)
                else: ## within tns date,
                    sub_cost = min_dp + min(Vmtc_row, Vmtc_col)
                    if(i!=j):## tns
                        sub_cost = min_dp + w3*min(Vmtc_row, Vmtc_col)
            dp[i][j] = min(insertion_cost, deletion_cost, sub_cost)
    return dp[sizerow - 1][sizecol - 1], dp

def Levenshtein_Distance_with_Transposition_Date_No_Matrix(seq1, seq2, dates1, dates2, dict_pre_matrix, max_transposition_date):
    """
    Calculates the Levenshtein distance between two sequences, considering transpositions.
    Args:
    seq1: The first sequence.
    seq2: The second sequence.
    dict_sub_matrix: Pandas DataFrame containing substitution distance.
    Returns:
    The Levenshtein distance between the two sequences.
    """
    seq1 = ["#"] +  [x for x in seq1]
    seq2 = ["#"] +  [x for x in seq2]
    dates1 = ["None"] + [x for x in dates1]
    dates2 = ["None"] + [x for x in dates2]
    
    sizerow = len(seq1)
    sizecol = len(seq2)
    # Create a distance matrix
    dp = [[0 for col in range(sizecol)] for row in range(sizerow)]
    w1, w2, w3 = -0.5, 0.75, 0.5
    #in the manuscript, 𝑤1 = -0.5, 𝑤2 = 0.75, and 𝑤3 = 0.5
    ## Vsub = Vmtc * w1, (w1<=0)
    ## Vins = Vsub * w2 = Vmtc * w1*w2  ([0.5, 1])
    ## Vtns = Vmtc * w3  ([0,1])
    for i in range(1, sizerow):
        for j in range(1, sizecol):
            # Standard costs
            Vmtc_row = dict_pre_matrix[seq1[i]]["Vmtc"]
            Vmtc_col = dict_pre_matrix[seq2[j]]["Vmtc"]
            insertion_cost = dp[i][j-1] + w1*w2*min(Vmtc_row, Vmtc_col)  # ( # -> letter)
            deletion_cost = dp[i-1][j] + w1*w2*min(Vmtc_row, Vmtc_col)  # (letter -> # )
            # Substitution cost
            min_dp =  dp[i-1][j-1]
            if (seq1[i] != seq2[j]):
                sub_cost = min_dp + w1*min(Vmtc_row, Vmtc_col)  # sub
            ## change sub_cost if same sequence
            if (seq1[i] == seq2[j]): ## sub or tns or mtc
                if (abs((dates1[i] - dates2[j]).days) > max_transposition_date):
                    ## sub: same sequence, but out of date.
                    sub_cost = min_dp + w1*min(Vmtc_row, Vmtc_col)
                else: ## within tns date,
                    sub_cost = min_dp + min(Vmtc_row, Vmtc_col)
                    if(i!=j):## tns
                        sub_cost = min_dp + w3*min(Vmtc_row, Vmtc_col)
            dp[i][j] = min(insertion_cost, deletion_cost, sub_cost)
    return dp[sizerow - 1][sizecol - 1], dp

# %%
dict_matrix = sub_matrix.df_matrix.to_dict('index')
#'''
seq1 = [('C', date(2024, 1, 1)),('D', date(2024, 1, 1)), ('A', date(2024, 1, 1)), ('B', date(2024, 1, 2))]#, ('F', date(2024, 1, 5))]
seq2 = [('A', date(2024, 1, 1)),('B', date(2024, 1, 1)), ('C', date(2024, 1, 3)), ('D', date(2024, 1, 4))]#, ('E', date(2024, 1, 5))]

df_seq1 = pd.DataFrame(data = seq1, columns= ["dx", "date"]).sort_values('date')
df_seq2 = pd.DataFrame(data = seq2, columns= ["dx", "date"]).sort_values('date')
seq1 = ''.join(df_seq1.dx)
date1 = df_seq1.date.values
seq2 = ''.join(df_seq2.dx)
date2 = df_seq2.date.values
#'''

seq1_penal = [dict_rareness_matrix[char]['Vins'] for char in seq1] #[dict_matrix[char]["#"] for char in seq1]
seq2_penal = [dict_rareness_matrix[char]['Vins'] for char in seq2]# [dict_matrix[char]["#"] for char in seq2]

seq1_match = [dict_rareness_matrix[char]['Vmtc'] for char in seq1] #[dict_matrix[char][char] for char in seq1]
seq2_match = [dict_rareness_matrix[char]['Vmtc'] for char in seq2]

dis_max, dis_min = max(sum(seq1_penal), sum(seq2_penal)), min(sum(seq1_match), sum(seq2_match))

print (seq1, seq2, dis_max, dis_min)

for i in range(5):
    trans_date = i
    distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date_Final(seq1, seq2, date1, date2, dict_matrix, trans_date)
    print ("MSA matrix Distance:", distance)#, distance_matrix)

    dict_rareness_matrix = df_rareness_weighted.to_dict('index')
    distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date_No_Matrix(seq1, seq2, date1, date2, dict_rareness_matrix, trans_date)
    print ("MSA no matrix Distance:", distance)#, distance_matrix)
    #print (pd.DataFrame(data = distance_matrix, columns = ["#"]+ list(df_seq2.dx.values), index = ["#"]+ list(df_seq1.dx.values)))
#Similarity = Normalize_Levenshtein_Distance_Score(seq1, seq2, date1, date2, dict_matrix, 10)
#distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date_No_Matrix(seq1, seq2, date1, date2, dict_rareness_matrix, trans_date)
#print ("Distance:", distance, distance_matrix)
# Out:
# CDAB ABCD 26.76 -71.4
# MSA matrix Distance: 8.86
# MSA no matrix Distance: 8.86
# MSA matrix Distance: 6.859999999999999
# MSA no matrix Distance: 6.859999999999999
# MSA matrix Distance: 6.859999999999999
# MSA no matrix Distance: 6.859999999999999
# MSA matrix Distance: -3.41
# MSA no matrix Distance: -3.41
# MSA matrix Distance: -3.41
# MSA no matrix Distance: -3.41

# %%
#pd.DataFrame(data = dict_matrix)
id1, id2='P1', 'P1'
id1, id2='P0', 'P0'
df_seq1, seq1, date1 = Get_Sequence_Dates_From_pID(id1, df_groups)
df_seq2, seq2, date2 = Get_Sequence_Dates_From_pID(id2, df_groups)
dict_matrix = sub_matrix.df_matrix.to_dict('index')

len_test = 10
seq1 = seq1[0:len_test]
seq2 = seq2[0:len_test]
date1 = date1[0:len_test]
date2 = date2[0:len_test]

seq1_match = [dict_matrix[char][char] for char in seq1]
seq2_match = [dict_matrix[char][char] for char in seq2]
seq1_penal = [dict_matrix[char]["#"] for char in seq1]
seq2_penal = [dict_matrix[char]["#"] for char in seq2]

dis_max, dis_min = max(sum(seq1_penal), sum(seq2_penal)), min(sum(seq1_match), sum(seq2_match))

print (''.join(seq1), ''.join(seq2), dis_max, dis_min)

trans_date = 4

distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date_Final(seq1, seq2, date1, date2, dict_matrix, trans_date)
print ("Distance:", distance)#, distance_matrix)
pd.DataFrame(data = distance_matrix, columns = ["#"]+ list(seq2), index = ["#"]+ list(seq1))
# Out:
# HTUMTHDZLE HTUMTHDZLE 89.46000000000001 -238.56
# Distance: -238.56
#    #        H        T        U        M         T         H         D  \
# #  0   0.0000   0.0000   0.0000   0.0000    0.0000    0.0000    0.0000
# H  0 -20.7600  -8.1225  -0.3375   7.4475   12.6375    7.7850   10.4550
# T  0  -8.1225 -54.4600 -41.8225 -29.1850  -16.5475   -3.9100    8.7275
# U  0  -0.3375 -41.8225 -66.0400 -59.7550  -47.1175  -39.3325  -28.8775
# M  0   7.4475 -29.1850 -59.7550 -82.8000  -70.1625  -62.3775  -51.9225
# T  0  12.6375 -16.5475 -47.1175 -70.1625 -116.5000 -103.8625  -91.2250
# H  0   7.7850  -3.9100 -39.3325 -62.3775 -103.8625 -137.2600 -126.8050
# D  0  10.4550   8.7275 -28.8775 -51.9225  -91.2250 -126.8050 -165.1400
# Z  0   7.7850  20.4225 -22.5925 -45.6375  -78.5875 -119.0200 -154.6850
# L  0   8.6100  21.2475 -13.9825 -37.0275  -65.9500 -110.4100 -144.2300
# E  0  12.6375  25.2750  -1.3450 -24.3900  -53.3125  -97.7725 -131.5925
#
#           Z         L         E
# ...

# %%
cols = ["#", "H", "I", "T", "U"]
df_rareness_weighted.loc[cols, :]
# Out:
#        count   Vmtc   Vsub   Vins   Vtns
# event
# #        0.0   0.00   0.00   0.00   0.00
# H       15.0 -20.76  10.38   7.78 -10.38
# I       17.0 -16.76   8.38   6.29  -8.38
# T       10.0 -33.70  16.85  12.64 -16.85
# U       20.0 -11.58   5.79   4.34  -5.79

# %%
    K J
  0 1 2
T 1 0 1
J 2 1 -12

# %% [markdown]
# ##  rareness weighting  ref: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7647282/pdf/ocaa052.pdf
# #### With match values scaled between 1 and 10 in our dataset
# #### A (inpatient admission), which makes up 0.1% of events, has a match edit value of 10.0, while P (primary care visits), which makes up 11.7% of events, has a match edit value of 2.2.

# %%
def Return_Matrix_From_Multiprocessing_Output(_path_output):
    """
    Return_Matrix_From_Multiprocessing_Output
    Output: 
    P2_P0	0.2834645669291339
    P3_P0	0.2818791946308725
    ...
    """
    df_tem = pd.read_csv(_path_output, sep='\t', header=None)
    len_df_tem = len(df_tem)
    num_matrix = int(np.sqrt(2*len_df_tem))+1
    print ("N_Pairs: " + str(len_df_tem) + " ~= Matrix Size: " + str(num_matrix))
    
    df_tem_idx = df_tem.loc[:, 0].str.split('_', expand=True)
    matrix_idx = sorted(np.unique(df_tem_idx.values))
    
    df_out_matrix = pd.DataFrame(data = np.diag(np.full(len(matrix_idx), 1.0)),
                                 columns = matrix_idx, index = matrix_idx)
    
    for idx in df_tem_idx.iterrows():
        #print (idx[0], idx[1])
        x = idx[1][0]
        y = idx[1][1]
        score = df_tem.loc[idx[0], 1]
        df_out_matrix.loc[x, y] = score
        df_out_matrix.loc[y, x] = score
        #break
    return df_out_matrix.iloc[0:num_matrix, 0:num_matrix]

import re

def If_contain_letter(index_value):
    return bool(re.search(r'[a-zA-Z]', index_value))

def Negative_Log_Transform_and_Scale(values, scale_min=2, scale_max=50):
    """
    ## edit values scaled between 1 and 10 by rareness weighting
    ## apply a negative log transformation "rarer events = a higher value"
    """
    # Apply the negative log transformation
    transformed_values = -np.log(values)
    # Normalize the transformed values to the range [scale_min, scale_max]
    min_val = np.min(transformed_values)
    max_val = np.max(transformed_values)
    scaled_values = scale_min + (transformed_values - min_val) * (scale_max - scale_min) / (max_val - min_val)
    return -1.0*scaled_values

def Return_Rareness_Weighted_Matrix(_df, w1=-0.5, w2=0.75, w3=0.5):
    #in the manuscript, 𝑤1 = -0.5, 𝑤2 = 0.75, and 𝑤3 = 0.5
    ## Vsub = Vmtc * w1, (w1<=0)
    ## Vins = Vsub * w2 = Vmtc * w1*w2  ([0.5, 1])
    ## Vtns = Vmtc * w3  ([0,1])
    #w1, w2, w3 = -0.5, 0.75, 0.5
    _df.loc[:, "Vmtc"] = Negative_Log_Transform_and_Scale(_df.loc[:, 'count'])
    _df.loc[:, "Vsub"] = w1 * _df.loc[:, "Vmtc"]
    _df.loc[:, "Vins"] = w1*w2 * _df.loc[:, "Vmtc"]
    _df.loc[:, "Vtns"] = w3 * _df.loc[:, "Vmtc"]
    _df.loc["#", :] = 0
    return round(_df,2)#.astype(int)

# %%
df_rareness_weighted.head(3)
# Out:
#        count   Vmtc  Vsub  Vins  Vtns
# event
# B       27.0  -2.00  1.00  0.75 -1.00
# U       20.0 -11.58  5.79  4.34 -5.79
# R       19.0 -13.21  6.61  4.96 -6.61

# %%
## generate sub matrix from data itself

Path_data = "demo_Input_File.tsv"

df_tem = pd.read_csv(Path_data, sep='\t')
col_seq = "event"
df_rareness_weighted = pd.DataFrame(data = df_tem.loc[:, col_seq].value_counts())
df_rareness_weighted = df_rareness_weighted[df_rareness_weighted.index.to_series().apply(If_contain_letter)]
df_rareness_weighted = Return_Rareness_Weighted_Matrix(df_rareness_weighted)
## from df_rareness_weighted to rewrite matrix
sub_matrix = SubstitutionMatrix(1)
seq = ''.join(df_tem.event)
sub_matrix.initate_matrix(seq, seq)
letters = df_rareness_weighted.index

#print ()
sub_matrix.df_matrix.loc["#", "#"] = 0
for idx in df_rareness_weighted.index.drop('#'):
    sub_matrix.set_score_2ways(idx, idx, df_rareness_weighted.loc[idx, 'Vmtc'])
    #print (df_rareness_weighted.loc[idx, 'Vins'])
    sub_matrix.set_score_2ways('#', idx, df_rareness_weighted.loc[idx, 'Vins']) #insert
    sub_matrix.set_score_2ways(idx, '#', df_rareness_weighted.loc[idx, 'Vins']) # del
    for idy in df_rareness_weighted.index.drop('#'):
        if (idx != idy):
            sub_matrix.set_score(idx, idy, df_rareness_weighted.loc[idx, 'Vsub'])
            sub_matrix.set_score(idy, idx, df_rareness_weighted.loc[idy, 'Vsub'])
# Out:
# /home/xli_p14/github/sentenceTransformers/src/MSA/objects.py:144: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.df_matrix.loc[event1, event2] = score
# /home/xli_p14/github/sentenceTransformers/src/MSA/objects.py:145: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   self.df_matrix.loc[event2, event1] = score
# /home/xli_p14/github/sentenceTransformers/src/MSA/objects.py:144: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-11.58' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
## read parallel output
path_output = "./src/MSA/test_output.txt"
#Return_Matrix_From_Multiprocessing_Output(path_output)

# %%
# Example usage
seq1 = "sitting"
seq2 = "kitten"

sub_matrix = Initate_Submatrix(seq1, seq2)
distance = levenshtein_distance(seq1, seq2, sub_matrix.df_matrix.to_dict())

# %% [markdown]
# ## generate random sample for testing

# %%
import random, datetime

def Get_Sequence_Dates_From_pID(_pid, df_groups):
    col_code = 'event'
    col_date = 'date'
    date_format = '%Y-%m-%d'
    df_seq1 = df_groups.get_group(_pid).loc[:, [col_code, col_date]].sort_values(col_date).drop_duplicates()
    seq1 = [x for x in df_seq1.loc[:, col_code]]
    date1 = [x for x in df_seq1.loc[:, col_date]]
    return df_seq1, seq1, date1
    
def Generate_Random_Event_Dates(_length_events):
  alphabet = []
  for i in range(ord('A'), ord('Z') + 1):
    letter = chr(i)
    alphabet.append(letter)

  start_date = datetime.date(2023, 1, 1)
  end_date = datetime.date(2024, 1, 1)
  dates=[]
  for day in range((end_date - start_date).days):
    dates.append(start_date + datetime.timedelta(days=day)) 

  n_choices = _length_events

  events = ''.join(random.choices(alphabet, k=n_choices))
  dates = sorted(random.choices(dates, k=n_choices))
  return events, dates

output_table = []
for name in range(0,10,1):
    name = "P"+str(name)
    length = random.randrange(20,50)
    #print (name, length)
    events, dates = Generate_Random_Event_Dates(length)
    for event, date in zip(events, dates):
        output_table.append([name, event, date])

df_tem = pd.DataFrame(data = output_table, columns= ["ID", "event", "date"])
df_tem.to_csv("demo_Input_File.tsv", sep='\t', index=None)

# %%
Path_data = "demo_Input_File.tsv"
path_matrix = "test_submatrix.txt"

col_ID = 'ID'
col_time = 'date'
col_seq = 'event'
max_transposition_date = 10
df_tem = pd.read_csv(Path_data, sep='\t')
df_tem.loc[:, 'date'] = pd.to_datetime(df_tem.loc[:, col_time])
#dict_matrix = pd.read_csv(path_matrix, sep='\t', index_col=0).to_dict()
dict_matrix = sub_matrix.df_matrix.to_dict()
## for each person, merge events if happen within a date #df_p1.drop_duplicates()
df_groups = df_tem.groupby(col_ID)
IDs = list(df_groups.groups.keys())
similarity_matrix = []

'''
import time
start_time = time.time()
for idx in range(len(IDs)):
    print ("Process ID: ", idx)
    for idj in range(idx):
        df_p1 = df_groups.get_group(IDs[idx]).loc[:, [col_time, col_seq]].drop_duplicates()
        df_p2 = df_groups.get_group(IDs[idj]).loc[:, [col_time, col_seq]].drop_duplicates()
        pair_name = IDs[idx] + "_" + IDs[idj]
        Similarity = Main_Compute_Similarity_For_Pair(pair_name, df_p1, df_p2, col_seq, col_time, dict_matrix, max_transposition_date)
        similarity_matrix.append([pair_name, Similarity])
end_time = time.time()
elapsed_time = end_time - start_time

print("Elapsed time:", elapsed_time, "seconds")
'''
# Out:
# '\nimport time\nstart_time = time.time()\nfor idx in range(len(IDs)):\n    print ("Process ID: ", idx)\n    for idj in range(idx):\n        df_p1 = df_groups.get_group(IDs[idx]).loc[:, [col_time, col_seq]].drop_duplicates()\n        df_p2 = df_groups.get_group(IDs[idj]).loc[:, [col_time, col_seq]].drop_duplicates()\n        pair_name = IDs[idx] + "_" + IDs[idj]\n        Similarity = Main_Compute_Similarity_For_Pair(pair_name, df_p1, df_p2, col_seq, col_time, dict_matrix, max_transposition_date)\n        similarity_matrix.append([pair_name, Similarity])\nend_time = time.time()\nelapsed_time = end_time - start_time\n\nprint("Elapsed time:", elapsed_time, "seconds")\n'

# %%
A = Person(df_tem.ID[0])
A.set_story(seq1, date1)
A.visualize_history()

# %%
seq1 = [('C', date(2024, 1, 1)),('D', date(2024, 1, 1)), ('A', date(2024, 1, 3)), ('B', date(2024, 1, 4)), ('F', date(2024, 1, 5))]
seq2 = [('A', date(2024, 1, 1)),('B', date(2024, 1, 2)), ('C', date(2024, 1, 3)), ('D', date(2024, 1, 4)), ('E', date(2024, 1, 5))]

df_seq1 = pd.DataFrame(data = seq1, columns= ["dx", "date"]).sort_values('date')
df_seq2 = pd.DataFrame(data = seq2, columns= ["dx", "date"]).sort_values('date')
seq1 = ''.join(df_seq1.dx)
date1 = df_seq1.date.values
seq2 = ''.join(df_seq2.dx)
date2 = df_seq2.date.values
sub_matrix = Initate_Submatrix(seq1, seq2)

distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date(seq1, seq2, date1, date2, df_sub_matrix, 1)
#print ("Distance:", distance)
Similarity = Normalize_Levenshtein_Distance_Score(seq1, seq2, date1, date2, sub_matrix.df_matrix.to_dict(), 3)
Similarity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 12
#       9 date2 = df_seq2.date.values
#      10 sub_matrix = Initate_Submatrix(seq1, seq2)
# ---> 12 distance, distance_matrix = Levenshtein_Distance_with_Transposition_Date(seq1, seq2, date1, date2, df_sub_matrix, 1)
#      13 #print ("Distance:", distance)
#      14 Similarity = Normalize_Levenshtein_Distance_Score(seq1, seq2, date1, date2, sub_matrix.df_matrix.to_dict(), 3)
#
# NameError: name 'df_sub_matrix' is not defined

# %%
sub_matrix = SubstitutionMatrix(1)
sub_matrix.initate_matrix(seq1, seq2)
sub_matrix.save_matrix_json("test_submatrix")

path_dict_sub_matrix = "test_submatrix.json"

with open(path_dict_sub_matrix, "r") as f:
    dict_sub_matrix = json.load(f)
# !python ./src/MSA/MSA.py "{seq1}" "{seq2}" "{date1}" "{date2}" "{path_dict_sub_matrix}" 10
# Out:
# Traceback (most recent call last):
#   File "/home/xli_p14/github/sentenceTransformers/src/MSA/MSA.py", line 109, in <module>
#     main()
#   File "/home/xli_p14/github/sentenceTransformers/src/MSA/MSA.py", line 97, in main
#     dates1 = date(sys.argv[3])
#   File "/home/xli_p14/miniconda3/envs/pypy/lib/pypy3.9/datetime.py", line 858, in __new__
#     year, month, day = _check_date_fields(year, month, day)
#   File "/home/xli_p14/miniconda3/envs/pypy/lib/pypy3.9/datetime.py", line 424, in _check_date_fields
#     year = _check_int_field(year)
#   File "/home/xli_p14/miniconda3/envs/pypy/lib/pypy3.9/datetime.py", line 420, in _check_int_field
#     raise TypeError('an integer is required (got type %s)' %
# TypeError: an integer is required (got type str)

# %%
B = Person("LALAL")
B.set_story_df(df_seq1, 'dx', 'date')
B.visualize_history()

# %% [markdown]
# ## appendix

# %%
## generate matrix
seq1 = ''.join(df_tem.loc[:, col_seq])

sub_matrix = SubstitutionMatrix(1)
sub_matrix.initate_matrix(seq1, seq1)
sub_matrix.df_matrix
sub_matrix.save_df_matrix_txt(path_matrix)
filename = "test_output.txt"
with open(filename, 'a') as f:
    f.write(pair_name+'\t'+ str(Similarity)+'\n')
    time.sleep(0.01)
